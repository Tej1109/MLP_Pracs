# %% [markdown]
# <a href="https://colab.research.google.com/github/Tej1109/MLP_Pracs/blob/main/Tejas_MLP_Prac_3_Data_Manipulation_and_Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#Dataset taken from w3schools
data = {
    "Car": ["Toyota", "Mitsubishi", "Skoda", "Fiat", "Mini", "VW", "Skoda", "Mercedes", "Ford", "Audi"],
    "Model": ["Aygo", "Space Star", "Citigo", "500", "Cooper", "Up!", "Fabia", "A-Class", "Fiesta", "A1"],
    "Volume": [1.0, 1.2, 1.0, 0.9, 1.5, 1.0, 1.4, 1.5, 1.5, 1.6],
    "Weight": [790, 1160, 929, 865, 1140, 929, 1109, 1365,None, 1150],
    "CO2": [99, 95, 95, 90, 105, 105, 90, 92, 98, 99]
}

df = pd.DataFrame(data)

df.to_csv('cars.csv', index=False)

print("CSV file 'cars.csv' created!")
# Out:
# CSV file 'cars.csv' created!

# %%
df
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyota        Aygo     1.0   790.0   99
# 1  Mitsubishi  Space Star     1.2  1160.0   95
# 2       Skoda      Citigo     1.0   929.0   95
# 3        Fiat         500     0.9   865.0   90
# 4        Mini      Cooper     1.5  1140.0  105
# 5          VW         Up!     1.0   929.0  105
# 6       Skoda       Fabia     1.4  1109.0   90
# 7    Mercedes     A-Class     1.5  1365.0   92
# 8        Ford      Fiesta     1.5     NaN   98
# 9        Audi          A1     1.6  1150.0   99

# %% [markdown]
# ### Data Manipulation

# %%
#Checking for duplicates
df.duplicated().sum() #0 Duplicates
# Out:
# np.int64(0)

# %%
#Imputing mean for Nan Value
df.fillna({"Weight" : df['Weight'].mean()}, inplace = True)
df
# Out:
#           Car       Model  Volume       Weight  CO2
# 0      Toyota        Aygo     1.0   790.000000   99
# 1  Mitsubishi  Space Star     1.2  1160.000000   95
# 2       Skoda      Citigo     1.0   929.000000   95
# 3        Fiat         500     0.9   865.000000   90
# 4        Mini      Cooper     1.5  1140.000000  105
# 5          VW         Up!     1.0   929.000000  105
# 6       Skoda       Fabia     1.4  1109.000000   90
# 7    Mercedes     A-Class     1.5  1365.000000   92
# 8        Ford      Fiesta     1.5  1048.555556   98
# 9        Audi          A1     1.6  1150.000000   99

# %%
#Feature Extraction
df['CO2 per CC'] = df['CO2']/(df['Volume'] * 1000) #Extracted co2 per cc, this is data manipulation
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2  CO2 per CC
# 0      Toyota        Aygo     1.0   790.0   99    0.099000
# 1  Mitsubishi  Space Star     1.2  1160.0   95    0.079167
# 2       Skoda      Citigo     1.0   929.0   95    0.095000
# 3        Fiat         500     0.9   865.0   90    0.100000
# 4        Mini      Cooper     1.5  1140.0  105    0.070000

# %% [markdown]
# ### Scaling Data

# %%
#Scaler - MinMax
from sklearn.preprocessing import MinMaxScaler

df2 = df.copy()
scaler = MinMaxScaler()
for i in df.columns:
  if df2[i].dtype == int or df2[i].dtype == float:
    df2[i] = scaler.fit_transform(df2[i].values.reshape(-1, 1))
df2
# Out:
#           Car       Model    Volume    Weight       CO2  CO2 per CC
# 0      Toyota        Aygo  0.142857  0.000000  0.600000    0.862595
# 1  Mitsubishi  Space Star  0.428571  0.643478  0.333333    0.408397
# 2       Skoda      Citigo  0.142857  0.241739  0.333333    0.770992
# 3        Fiat         500  0.000000  0.130435  0.000000    0.885496
# 4        Mini      Cooper  0.857143  0.608696  1.000000    0.198473
# 5          VW         Up!  0.142857  0.241739  1.000000    1.000000
# 6       Skoda       Fabia  0.714286  0.554783  0.000000    0.067612
# 7    Mercedes     A-Class  0.857143  1.000000  0.133333    0.000000
# 8        Ford      Fiesta  0.857143  0.449662  0.533333    0.091603
# 9        Audi          A1  1.000000  0.626087  0.600000    0.012405

# %%
#Scaler - Standard
from sklearn.preprocessing import StandardScaler

df3 = df.copy()
scaler = StandardScaler()
for i in df.columns:
  if df3[i].dtype == int or df3[i].dtype == float:
    df3[i] = scaler.fit_transform(df3[i].values.reshape(-1, 1))
df3
# Out:
#           Car       Model    Volume        Weight       CO2  CO2 per CC
# 0      Toyota        Aygo -1.024544 -1.591317e+00  0.425285    1.119456
# 1  Mitsubishi  Space Star -0.236433  6.859006e-01 -0.347960   -0.055245
# 2       Skoda      Citigo -1.024544 -7.358216e-01 -0.347960    0.882541
# 3        Fiat         500 -1.418599 -1.129719e+00 -1.314516    1.178684
# 4        Mini      Cooper  0.945732  5.628078e-01  1.585152   -0.598174
# 5          VW         Up! -1.024544 -7.358216e-01  1.585152    1.474827
# 6       Skoda       Fabia  0.551677  3.720139e-01 -1.314516   -0.936623
# 7    Mercedes     A-Class  0.945732  1.947602e+00 -0.927894   -1.111488
# 8        Ford      Fiesta  0.945732  1.399404e-15  0.231973   -0.874574
# 9        Audi          A1  1.339788  6.243542e-01  0.425285   -1.079406
